# %%
x = 1:100 / 10
y = cos(x)
x = sin(x)

# %%
plot(convolve(x, y, type = 'open'))
par(new=TRUE)
plot(x, type = 'l')
par(new=TRUE)
plot(y, type = 'l')
# Out:
# plot without title

# %%
plot(convolve(y, x, type = 'open'))
lines(x)
lines(y)
# Out:
# plot without title
